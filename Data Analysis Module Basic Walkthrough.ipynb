# %% [markdown]
# # CHOP Academic Entrepreneurship Data Analysis Module Walkthrough
#
# Author: Robert Zhang - University of Pennsylvania, B.S.E Computer Science, B.S.E. Economics (SEAS '22, WH '22)
#
# Additional Contributors: Jaimie Rosenberg, Michael Sosnowski
#
# Requirements: Anaconda (with Python 3)
# <ul>
#     <li>Install most recent version of Anaconda</li>
# </ul>
#
# ## Introduction
#
# This module presents an automated way to collect, analysis, and display data from the Scholarly Commons data source for the Children's Hospital of Philadelphia's Academic Entrepreneurship textbook.
#
# Below are some methods the module provides

# %% [markdown]
# ## Module Initialization

# %%
from GUIModule import *

g = GUIModule()

# %% [markdown]
# ## Total Downloads Over Time

# %%
g.plotDownloadsOverTime(cumulative=True)
g.plotDownloadsOverTime()

# %% [markdown]
# ## Number of Downloads by Country Over Time
#
# The top 10 countries are by default displayed, with the remaining grouped under "other". More or less countries can be displayed using the cutoff parameter. Countries are sorted top to bottom in terms of download frequency. The bottom line is the most frequent country's line.

# %%
g.plotDownloadsByCountryOverTime()
g.plotDownloadsByCountryOverTime(cutoff=5) #Cutoff set to 5 countries + others
g.plotDownloadsByCountryOverTime(cutoff=5,normalized=True) #Cutoff set to 5 countries + others

g.plotDownloadsByCountryOverTime(cutoff=5,cumulative=True)
g.plotDownloadsByCountryOverTime(cutoff=5,cumulative=True,stacked=True)
g.plotDownloadsByCountryOverTime(cutoff=5,cumulative=False,stacked=True)

# %% [markdown]
# ## Number of Downloads by Institution Over Time
#
# The top 10 institutions are by default displayed, with the remaining grouped under "other". More or less institutions can be displayed using the cutoff parameter. Institutions are sorted top to bottom in terms of download frequency. The bottom line is the most frequent institution's line.

# %%
g.plotDownloadsByInstitutionOverTime()
g.plotDownloadsByInstitutionOverTime(cutoff=5)

g.plotDownloadsByInstitutionOverTime(cutoff=5,cumulative=True)
g.plotDownloadsByInstitutionOverTime(cutoff=5,cumulative=True,stacked=True)

# %% [markdown]
# ## Number of Downloads by Institution Type Over Time
# Institution types are unsorted

# %%
g.plotDownloadsByInstitutionTypeOverTime()
g.plotDownloadsByInstitutionTypeOverTime(normalized=True)

g.plotDownloadsByInstitutionTypeOverTime(cumulative=True)
g.plotDownloadsByInstitutionTypeOverTime(cumulative=True,stacked=True)

# %% [markdown]
# ## Number of Downloads by CHOP Affiliates vs All Downloads Over Time

# %%
g.plotDownloadsByAffiliatesOverTime()
g.plotDownloadsByAffiliatesOverTime(cumulative=True)
g.plotDownloadsByAffiliatesOverTime(cumulative=True,stacked=True)
g.plotDownloadsByAffiliatesOverTime(normalized=True)

# %% [markdown]
# ## Number of Downloads by CHOP Affiliates vs Educational Downloads Over Time

# %%
g.plotDownloadsByAffiliatesOverTimeEducational()
g.plotDownloadsByAffiliatesOverTimeEducational(cumulative=True)
g.plotDownloadsByAffiliatesOverTimeEducational(cumulative=True,stacked=True)
g.plotDownloadsByAffiliatesOverTimeEducational(normalized=True)

# %% [markdown]
# ## Number of Downloads by Institutional vs NonInstitutional Over Time

# %%
g.plotInstNonInstDownloadsOverTime()

g.plotInstNonInstDownloadsOverTime(cumulative=True)
g.plotInstNonInstDownloadsOverTime(cumulative=True,stacked=True)

# %% [markdown]
# ## Number of Downloads by Article Over Time
#
# The top 10 articles are by default displayed, with the remaining grouped under "other". More or less articles can be displayed using the cutoff parameter. Articles are sorted top to bottom in terms of download frequency. The bottom line is the most frequent article's line.

# %%
g.plotDownloadsByArticleOverTime()
g.plotDownloadsByArticleOverTime(cutoff=5)

g.plotDownloadsByArticleOverTime(cutoff=5,cumulative=True)
g.plotDownloadsByArticleOverTime(cutoff=5,cumulative=True,stacked=True)

# %% [markdown]
# ## Number of Downloads by Article Category Over Time
# To be "balanced" is to weight downloads by the number of articles in that category, such that the number of articles in each category doesn't bias the results. To be "normalized" is to find the percentages per period.

# %%
g.plotCategoriesDownloadedOverTime()
g.plotCategoriesDownloadedOverTime(balanced = True)
g.plotCategoriesDownloadedOverTime(normalized = True)
g.plotCategoriesDownloadedOverTime(balanced=True, normalized = True)

g.plotCategoriesDownloadedOverTime(cumulative=True)
g.plotCategoriesDownloadedOverTime(balanced = True,cumulative=True)
g.plotCategoriesDownloadedOverTime(cumulative=True,stacked=True)
g.plotCategoriesDownloadedOverTime(balanced = True,cumulative=True,stacked=True)

# %% [markdown]
# ## Number of Downloads by Article in Aggregate
# The top 10 articles are by default displayed, with the remaining grouped under "other". Below is listed the top 50 most downloaded articles.

# %%
g.plotMostDownloadedArticles(50)
g.printMostDownloadedArticles(50)
# Out:
# Orphan Drugs: Understanding the FDA Approval Process
# FDA Device Regulation: 510(k), PMA
# Developing In Vitro Diagnostics for Commercialization and Clinical Implementation
# Writing Business Plans for a Life Science Startup or Clinical Program
# Intellectual Property Protection for Biologics
# FDA Drug Regulation: Investigational New Drug Applications
# Innate Biases
# Preclinical Animal Models
# SBIR/STTR Grants: Application Guidance
# Accelerators and Incubators
# Equity Allocation in Startups
# Human-Centered Design: Understanding Customers’ Needs Through Discovery and Interviewing
# Reimbursement Strategies and CPT Codes for Device Development
# Overview of Drug Development
# Does My Invention Already Exist? Conducting a Patent / Prior Art Search
# Building a Successful Startup Team
# Identifying Unmet Needs: Problems that Need Solutions
# What is Academic Entrepreneurship?
# Intellectual Property: Commercializing in a University Setting
# ...

# %% [markdown]
# ## List Articles With Less Than N Downloads
# Sorted from most to least downloaded

# %%
g.printArticlesWithLessThanNDownloads(30)
# Out:
# Draft - Forming and Maintaining Meaningful Partnerships: Academic Scientists and Corporations
# Marketing in an Academic Institution
# Forming and Maintaining Meaningful Partnerships Between Academic Scientists and Corporations
# Nonprofit and Foundation Sponsored Research: Developing New Models of Collaboration for Research and Development

# %% [markdown]
# In similar vein, articles with no downloads

# %%
g.printArticlesWithNoDownloads()

# %% [markdown]
# ## Number of Downloads by Referral Source Over Time
#
# The top 10 sources are by default displayed, with the remaining grouped under "other". More or less sources can be displayed using the cutoff parameter. Sources are sorted top to bottom in terms of download frequency. The bottom line is the most frequent source's line.

# %%
g.plotDownloadsByReferralSourceOverTime(5)

g.plotDownloadsByReferralSourceOverTime(5,cumulative=True)
g.plotDownloadsByReferralSourceOverTime(5,cumulative=True,stacked=True)

# %% [markdown]
# ## Most Downloaded Articles By Institution Type

# %%
g.printMostDownloadedArticlesByInstitutionType("Education")
# Out:
# Human-Centered Design: Understanding Customers’ Needs Through Discovery and Interviewing
# What is Academic Entrepreneurship?
# FDA Device Regulation: 510(k), PMA
# Writing Business Plans for a Life Science Startup or Clinical Program
# FDA Drug Regulation: Investigational New Drug Applications
# Resources at Academic Entrepreneurship Centers
# Building a Successful Startup Team
# Orphan Drugs: Understanding the FDA Approval Process
# Preclinical Animal Models
# I-Corps as a Training Tool for New Technology Development
# Identifying Unmet Needs: Problems that Need Solutions
# Intellectual Property: Ownership and Protection in a University Setting
# Overview of Device Development
# Does My Invention Already Exist? Conducting a Patent / Prior Art Search
# SBIR/STTR Grants: Application Guidance
# The Promotion Process: Academic Entrepreneurship Career Tracks
# Intrapreneurship:  Strategic Approaches for Managing Disruptive Innovation in Clinical and Research Projects
# ...

# %%
g.printMostDownloadedArticlesByInstitutionType("Commercial")
# Out:
# Orphan Drugs: Understanding the FDA Approval Process
# FDA Device Regulation: 510(k), PMA
# Intellectual Property Protection for Biologics
# FDA Drug Regulation: Investigational New Drug Applications
# Developing In Vitro Diagnostics for Commercialization and Clinical Implementation
# Preclinical Animal Models
# Writing Business Plans for a Life Science Startup or Clinical Program
# Accelerators and Incubators
# Equity Allocation in Startups
# Overview of Drug Development
# Reimbursement Strategies and CPT Codes for Device Development
# Digital Health: Software as a Medical Device
# Human-Centered Design: Understanding Customers’ Needs Through Discovery and Interviewing
# Strategic Planning and Costs of FDA Regulation
# Development of Radiographic Contrast Agents for Diagnostic Imaging
# Intellectual Property: Commercializing in a University Setting
# SBIR/STTR Grants: Application Guidance
# Identifying Unmet Needs: Problems that Need Solutions
# Innate Biases
# ...

# %%
g.printMostDownloadedArticlesByInstitutionType("Government")
# Out:
# Orphan Drugs: Understanding the FDA Approval Process
# Intellectual Property Protection for Biologics
# Does My Invention Already Exist? Conducting a Patent / Prior Art Search
# Clinical and Translational Science Awards
# Careers in Academia and Industry: Transitions and Challenges
# Innate Biases
# FDA Drug Regulation: Investigational New Drug Applications
# Human-Centered Design: Understanding Customers’ Needs Through Discovery and Interviewing
# Development of Radiographic Contrast Agents for Diagnostic Imaging
# Pediatric Medical Device Development Pathways
# Preclinical Animal Models
# Accelerators and Incubators
# Digital Health: Software as a Medical Device
# Strategic Planning and Costs of FDA Regulation
# SBIR/STTR Grants: Application Guidance
# Overview of Drug Development
# Reimbursement Strategies and CPT Codes for Device Development
# FDA Device Regulation: 510(k), PMA
# Writing Business Plans for a Life Science Startup or Clinical Program
# ...

# %%
g.printMostDownloadedArticlesByInstitutionType("Military")
# Out:
# Department of Defense: SBIR/STTR Grants and Other Contracts
# SBIR/STTR Grants: Application Guidance
# Intrapreneurship:  Strategic Approaches for Managing Disruptive Innovation in Clinical and Research Projects

# %%
g.printMostDownloadedArticlesNonInstitutional()
# Out:
# Orphan Drugs: Understanding the FDA Approval Process
# Developing In Vitro Diagnostics for Commercialization and Clinical Implementation
# FDA Device Regulation: 510(k), PMA
# Writing Business Plans for a Life Science Startup or Clinical Program
# Intellectual Property Protection for Biologics
# Innate Biases
# FDA Drug Regulation: Investigational New Drug Applications
# SBIR/STTR Grants: Application Guidance
# Preclinical Animal Models
# Accelerators and Incubators
# Equity Allocation in Startups
# Reimbursement Strategies and CPT Codes for Device Development
# Overview of Drug Development
# Human-Centered Design: Understanding Customers’ Needs Through Discovery and Interviewing
# Does My Invention Already Exist? Conducting a Patent / Prior Art Search
# Building a Successful Startup Team
# Startup Company Formation and Management
# Social Entrepreneurship in Healthcare
# Digital Health: Software as a Medical Device
# Identifying Unmet Needs: Problems that Need Solutions
# ...
